# %% [markdown]
# Adds Appropriate Packages

# %%
using Pkg
Pkg.add("FileIO")
Pkg.add("MAT")
Pkg.add("Plots")
Pkg.add("Glob")
Pkg.add("StatsPlots")
Pkg.add("Statistics")
using FileIO, MAT, Plots, Glob, StatsPlots, Statistics
# Out:
#     Updating registry at `~/.julia/registries/General`
#     Updating git-repo `https://github.com/JuliaRegistries/General.git`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`

# %% [markdown]
# Read Individual MATLAB Files

# %%
# Define a function to read a single MATLAB file
function read_mat_file(filename)
    mat = matread(filename)
    # do something with the contents of the MATLAB file
    return mat
end
# Out:
# read_mat_file (generic function with 1 method)

# %% [markdown]
# Read Multiple MATLAB Files

# %%
function read_mat_files(filenames)
    data = []
    for filename in filenames
        push!(data, read_mat_file(filename))
    end
    return data
end
# Out:
# read_mat_files (generic function with 1 method)

# %% [markdown]
# Read All Files From Directory

# %%
filenames = readdir("/Users/byronpetselis/Desktop/Cancer_Data/Yeoh/ben", join=true, sort=false)
# read all the files in this directory
# Out:
# 1052-element Vector{String}:
#  "/Users/byronpetselis/Desktop/Cancer_Data/ben/Q10_I390_lesion_masked.mat"
#  "/Users/byronpetselis/Desktop/Cancer_Data/ben/Q10_I390_normal_masked.mat"
#  "/Users/byronpetselis/Desktop/Cancer_Data/ben/Q10_I452_lesion_masked.mat"
#  "/Users/byronpetselis/Desktop/Cancer_Data/ben/Q10_I452_normal_masked.mat"
#  "/Users/byronpetselis/Desktop/Cancer_Data/ben/Q10_I500_lesion_masked.mat"
#  "/Users/byronpetselis/Desktop/Cancer_Data/ben/Q10_I500_normal_masked.mat"
#  "/Users/byronpetselis/Desktop/Cancer_Data/ben/Q10_afast390_lesion_masked.mat"
#  "/Users/byronpetselis/Desktop/Cancer_Data/ben/Q10_afast390_normal_masked.mat"
#  "/Users/byronpetselis/Desktop/Cancer_Data/ben/Q10_afast452_lesion_masked.mat"
#  "/Users/byronpetselis/Desktop/Cancer_Data/ben/Q10_afast452_normal_masked.mat"
#  "/Users/byronpetselis/Desktop/Cancer_Data/ben/Q10_afast500_lesion_masked.mat"
#  "/Users/byronpetselis/Desktop/Cancer_Data/ben/Q10_afast500_normal_masked.mat"
#  "/Users/byronpetselis/Desktop/Cancer_Data/ben/Q10_aveLT390_lesion_masked.mat"
#  ⋮
#  "/Users/byronpetselis/Desktop/Cancer_Data/ben/Q9_tfast452_lesion_masked.mat"
#  "/Users/byronpetselis/Desktop/Cancer_Data/ben/Q9_tfast452_normal_masked.mat"
#  "/Users/byronpetselis/Desktop/Cancer_Data/ben/Q9_tfast500_lesion_masked.mat"
#  "/Users/byronpetselis/Desktop/Cancer_Data/ben/Q9_tfast500_normal_masked.mat"
#  "/Users/byronpetselis/Desktop/Cancer_Data/ben/Q9_tslow390_lesion_masked.mat"
#  "/Users/byronpetselis/Desktop/Cancer_Data/ben/Q9_tslow390_normal_masked.mat"
#  "/Users/byronpetselis/Desktop/Cancer_Data/ben/Q9_tslow452_lesion_masked.mat"
#  "/Users/byronpetselis/Desktop/Cancer_Data/ben/Q9_tslow452_normal_masked.mat"
#  "/Users/byronpetselis/Desktop/Cancer_Data/ben/Q9_tslow500_lesion_masked.mat"
#  "/Users/byronpetselis/Desktop/Cancer_Data/ben/Q9_tslow500_normal_masked.mat"
#  "/Users/byronpetselis/Desktop/Cancer_Data/ben/qben_norm_mean.mat"
#  "/Users/byronpetselis/Desktop/Cancer_Data/ben/qben_norm_std.mat"

# %%
data_Q1_lesion = read_mat_files(glob("Q1_*_lesion*","/Users/byronpetselis/Desktop/Cancer_Data/ben"))
# if you want to read all, read_mat_files(filenames)
# Out:
# 15-element Vector{Any}:
#  Dict{String, Any}("I390m" => [0.30558204391731475 0.30877930004276244 … 0.26887835478790495 0.2680878292365968])
#  Dict{String, Any}("I452m" => [0.43656608088831556 0.43417127544571565 … 0.44066936235037807 0.4422429417829722])
#  Dict{String, Any}("I500m" => [0.25785187519436975 0.25704942451152185 … 0.290452282861717 0.2896692289804309])
#  Dict{String, Any}("afast390m" => [0.8320896823177717 0.7974340018985594 … 0.6776569259640293 0.6430843291206774])
#  Dict{String, Any}("afast452m" => [0.7543488212982057 0.7484477087294225 … 0.7452942698576941 0.7332991870784018])
#  Dict{String, Any}("afast500m" => [0.7435782590015909 0.7501395015006879 … 0.8144889147739258 0.8289196940623698])
#  Dict{String, Any}("LT390m" => [6.718671668260087 6.589309675248273 … 6.325976143424427 6.2580914463601145])
#  Dict{String, Any}("LT452m" => [5.732591976745314 5.738054777595017 … 5.490369965190443 5.339554952606554])
#  Dict{String, Any}("LT500m" => [5.666916017333384 5.693900085120162 … 5.279949616893502 5.409192244281999])
#  Dict{String, Any}("tfast390m" => [3.667360014577209 3.587280228704615 … 2.67926796147932 2.5106176301114895])
#  Dict{String, Any}("tfast452m" => [2.115944018427226 2.1149866123769976 … 1.8326366947570931 1.7561313977767428])
#  Dict{String, Any}("tfast500m" => [1.3447299743956618 1.410951666484815 … 1.2199975524695585 1.3156753681894586])
#  Dict{String, Any}("tslow390m" => [11.94013463237686 10.930015120796838 … 8.925005630804229 8.521343295026211])
#  Dict{String, Any}("tslow452m" => [8.768332249993751 8.706203484399584 … 8.221065602800925 7.870208653763105])
#  Dict{String, Any}("tslow500m" => [8.10543904260447 8.25595737740615 … 8.339637844613971 8.840109093475956])

# %%
data_Q1_normal = read_mat_files(glob("Q1_*_normal*","/Users/byronpetselis/Desktop/Cancer_Data/ben"))
# Out:
# 15-element Vector{Any}:
#  Dict{String, Any}("I390nm" => [0.19635668625370237 0.19467948293983994 … 0.15509528414203103 0.15406569973066325])
#  Dict{String, Any}("I452nm" => [0.4968676518038693 0.4966379332896686 … 0.5077408717318598 0.5048623352323348])
#  Dict{String, Any}("I500nm" => [0.3067756619424283 0.30868258377049146 … 0.33716384412610917 0.3410719650370019])
#  Dict{String, Any}("afast390nm" => [0.6806128967630886 0.6532519797643165 … 0.6856208814749425 0.6456750375291622])
#  Dict{String, Any}("afast452nm" => [0.7656353893980397 0.7550191517929837 … 0.7282086616133866 0.7231805566887182])
#  Dict{String, Any}("afast500nm" => [0.7343372248296218 0.7451111039832895 … 0.8047315769763926 0.7938024634716646])
#  Dict{String, Any}("LT390nm" => [5.027210708571991 4.939678836690489 … 4.7500380407824885 4.5926540708584715])
#  Dict{String, Any}("LT452nm" => [5.657179977759689 5.649372314808186 … 4.940531351065248 4.951167714688134])
#  Dict{String, Any}("LT500nm" => [5.810886714614186 5.845172579153397 … 5.401625561761712 5.2190705994406015])
#  Dict{String, Any}("tfast390nm" => [2.0241953223156814 1.9594713750814494 … 1.7064112371337083 1.5508718095742946])
#  Dict{String, Any}("tfast452nm" => [2.2759701869286597 2.2422370798461477 … 1.8171442178465835 1.7887420867833363])
#  Dict{String, Any}("tfast500nm" => [1.6938122370578157 1.7146678231811592 … 1.5379193298794769 1.4314830871598234])
#  Dict{String, Any}("tslow390nm" => [7.129014255281355 6.8212521381906654 … 6.724215204007269 6.238314348590012])
#  Dict{String, Any}("tslow452nm" => [8.859677503371437 8.706548358592393 … 7.334688882920682 7.294500104151417])
#  Dict{String, Any}("tslow500nm" => [8.438618611156437 8.605813304086453 … 8.655984721150253 8.178656996029586])

# %%
feature_lesion_keys = []
feature_lesion_mean = []
feature_normal_mean = []
feature_normal_keys = []

for index in 1:15
    
    key_L = join(collect(keys(data_Q1_lesion[index])))
    value_L = collect(values(data_Q1_lesion[index]))
    mean_feature = mean(value_L[1])
    
#     println("key_L: $key_L mean: $mean_feature")
    
    push!(feature_lesion_mean, mean_feature)
    push!(feature_lesion_keys, key_L)
end


for index in 1:15
    
    key_N = join(collect(keys(data_Q1_normal[index])))
    value_N = collect(values(data_Q1_normal[index]))
    mean_feature = mean(value_N[1])
    
#     println("key_N: $key_N value_N: $value_N mean: $mean_feature")
    
    push!(feature_normal_mean, mean_feature)
    push!(feature_normal_keys, key_N)
end

# join() changes key data structure from Vector{String} to String

plot(
    bar(feature_lesion_keys, feature_lesion_mean, xlabel="Features", ylabel="Mean", legend=false), 
    xtickfontsize=5, 
    ytickfontsize=5, 
    xguidefontsize=8,
    yguidefontsize=8,
    xrotation = 45)

# %%
plot(
    bar(feature_normal_keys, feature_normal_mean, xlabel="Features", ylabel="Mean", legend=false), 
    xtickfontsize=5, 
    ytickfontsize=5, 
    xguidefontsize=8,
    yguidefontsize=8,
    xrotation = 45)

# %%
plot(feature_normal_keys, 
    [feature_normal_mean feature_lesion_mean], 
    label=["Q1 Normal" "Q1 Benign"], 
    xlabel="Features", 
    ylabel="Mean", 
    xrotation = 45, 
    seriestype=:scatter, 
    xtickfontsize=5, 
    ytickfontsize=5, 
    xguidefontsize=8,
    yguidefontsize=8,
    linewidth = 3)
