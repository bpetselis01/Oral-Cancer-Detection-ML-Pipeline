# %% [markdown]
# Adds Appropriate Packages

# %%
using Pkg
Pkg.add("FileIO")
Pkg.add("MAT")
Pkg.add("Plots")
Pkg.add("Glob")
Pkg.add("StatsPlots")
Pkg.add("Statistics")
using FileIO, MAT, Plots, Glob, StatsPlots, Statistics
# Out:
#     Updating registry at `~/.julia/registries/General`
#     Updating git-repo `https://github.com/JuliaRegistries/General.git`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`

# %% [markdown]
# Read Individual MATLAB Files

# %%
# Define a function to read a single MATLAB file
function read_mat_file(filename)
    mat = matread(filename)
    # do something with the contents of the MATLAB file
    return mat
end
# Out:
# read_mat_file (generic function with 1 method)

# %% [markdown]
# Read Multiple MATLAB Files

# %%
function read_mat_files(filenames)
    data = []
    for filename in filenames
        push!(data, read_mat_file(filename))
    end
    return data
end
# Out:
# read_mat_files (generic function with 1 method)

# %% [markdown]
# Read All Files From Directory

# %%
filenames = readdir("/Users/byronpetselis/Desktop/Cancer_Data/scc", join=true, sort=false)
# read all the files in this directory
# Out:
# IOError: readdir("/Users/byronpetselis/Desktop/Cancer_Data/scc"): no such file or directory (ENOENT)
#
# Stacktrace:
#  [1] uv_error
#    @ ./libuv.jl:97 [inlined]
#  [2] readdir(dir::String; join::Bool, sort::Bool)
#    @ Base.Filesystem ./file.jl:865
#  [3] top-level scope
#    @ In[4]:1

# %%
data_Q3_lesion = read_mat_files(glob("Q3_*_lesion*","/Users/byronpetselis/Desktop/Cancer_Data/scc"))
# if you want to read all, read_mat_files(filenames)
# Out:
# Any[]

# %%
data_Q3_normal = read_mat_files(glob("Q3_*_normal*","/Users/byronpetselis/Desktop/Cancer_Data/scc"))
# Out:
# Any[]

# %%
feature_lesion_keys = []
feature_lesion_mean = []
feature_normal_mean = []
feature_normal_keys = []

for index in 1:15
    
    key_L = join(collect(keys(data_Q3_lesion[index])))
    value_L = collect(values(data_Q3_lesion[index]))
    mean_feature = mean(value_L[1])
    
#     println("key_L: $key_L mean: $mean_feature")
    
    push!(feature_lesion_mean, mean_feature)
    push!(feature_lesion_keys, key_L)
end


for index in 1:15
    
    key_N = join(collect(keys(data_Q3_normal[index])))
    value_N = collect(values(data_Q3_normal[index]))
    mean_feature = mean(value_N[1])
    
#     println("key_N: $key_N value_N: $value_N mean: $mean_feature")
    
    push!(feature_normal_mean, mean_feature)
    push!(feature_normal_keys, key_N)
end

# join() changes key data structure from Vector{String} to String

plot(
    bar(feature_lesion_keys, feature_lesion_mean, xlabel="Features", ylabel="Mean", legend=false), 
    xtickfontsize=5, 
    ytickfontsize=5, 
    xguidefontsize=8,
    yguidefontsize=8,
    xrotation = 45)
# Out:
# BoundsError: attempt to access 0-element Vector{Any} at index [1]
#
# Stacktrace:
#  [1] getindex(A::Vector{Any}, i1::Int64)
#    @ Base ./array.jl:924
#  [2] top-level scope
#    @ ./In[7]:8

# %%
plot(
    bar(feature_normal_keys, feature_normal_mean, xlabel="Features", ylabel="Mean", legend=false), 
    xtickfontsize=5, 
    ytickfontsize=5, 
    xguidefontsize=8,
    yguidefontsize=8,
    xrotation = 45)

# %%
plot(feature_normal_keys, 
    [feature_normal_mean feature_lesion_mean], 
    label=["Q3 Normal" "Q3 Cancerous"], 
    xlabel="Features", 
    ylabel="Mean", 
    xrotation = 45, 
    seriestype=:scatter, 
    xtickfontsize=5, 
    ytickfontsize=5, 
    xguidefontsize=8,
    yguidefontsize=8,
    linewidth = 3)
